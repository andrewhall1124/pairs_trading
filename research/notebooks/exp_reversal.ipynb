# %%
from config import set_project_root
set_project_root()

# %%
import pandas as pd
import numpy as np
from finance_byu.summarize import summary
import matplotlib.pyplot as plt
import seaborn as sns
from research.datasets import CRSP
import statsmodels.formula.api as smf

# %%
# Read in crsp monthly data

df = CRSP().df.copy()

df.head()
# Out:
# LOADING CLEAN FILE
#    permno       date     cusip  shrcd  exchcd ticker  shrout     vol      prc  \
# 0   10000 1986-02-28  68391610   10.0     3.0  OMFGA  3680.0   828.0  3.25000
# 1   10000 1986-03-31  68391610   10.0     3.0  OMFGA  3680.0  1078.0  4.43750
# 2   10000 1986-04-30  68391610   10.0     3.0  OMFGA  3793.0   957.0  4.00000
# 3   10000 1986-05-30  68391610   10.0     3.0  OMFGA  3793.0  1074.0  3.10938
# 4   10000 1986-06-30  68391610   10.0     3.0  OMFGA  3793.0  1069.0  3.09375
#
#         ret
# 0 -0.257143
# 1  0.365385
# 2 -0.098592
# 3 -0.222656
# 4 -0.005025

# %%
# In sample
start = np.datetime64('1929-01-01')
end = np.datetime64('1982-12-31')

df = df[(df['date'] >= start) & (df['date'] <= end)]

df = df.reset_index(drop=True)

df
# Out:
#          permno       date     cusip  shrcd  exchcd ticker  shrout    vol  \
# 0         10006 1929-01-31  00080010   10.0     1.0   None   600.0  359.0
# 1         10006 1929-02-28  00080010   10.0     1.0   None   600.0  140.0
# 2         10006 1929-03-28  00080010   10.0     1.0   None   600.0  634.0
# 3         10006 1929-04-30  00080010   10.0     1.0   None   600.0  127.0
# 4         10006 1929-05-31  00080010   10.0     1.0   None   600.0  107.0
# ...         ...        ...       ...    ...     ...    ...     ...    ...
# 1226612   92946 1982-07-30  92922210   11.0     3.0   VYQT  1870.0    NaN
# 1226613   92946 1982-08-31  92922210   11.0     3.0   VYQT  1870.0    NaN
# 1226614   92946 1982-09-30  92922210   11.0     3.0   VYQT  1870.0    NaN
# 1226615   92946 1982-10-29  92922210   11.0     3.0   VYQT  1870.0    NaN
# 1226616   92946 1982-12-31  92922210   11.0     3.0   VYQT  1870.0  323.0
#
#               prc       ret
# 0         99.2500  0.011465
# 1         99.5000  0.002519
# 2        100.7500  0.027638
# 3         98.5000 -0.022333
# 4         94.0000 -0.045685
# ...           ...       ...
# 1226612       NaN       NaN
# 1226613       NaN       NaN
# 1226614       NaN       NaN
# 1226615       NaN       NaN
# 1226616    5.0625  0.025316
#
# [1226617 rows x 10 columns]

# %%
# Cleaning

df = df[['permno', 'ticker', 'date', 'prc', 'ret']].copy()

df['mdt'] = df['date'].dt.strftime("%Y-%m")
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year


df.head()
# Out:
#    permno ticker       date     prc       ret      mdt  month  year
# 0   10006   None 1929-01-31   99.25  0.011465  1929-01      1  1929
# 1   10006   None 1929-02-28   99.50  0.002519  1929-02      2  1929
# 2   10006   None 1929-03-28  100.75  0.027638  1929-03      3  1929
# 3   10006   None 1929-04-30   98.50 -0.022333  1929-04      4  1929
# 4   10006   None 1929-05-31   94.00 -0.045685  1929-05      5  1929

# %%
# Target Variable
df['ret_60_mean'] = df.groupby('permno')['ret'].rolling(59,59).mean().reset_index(drop=True)
df['ret_60_mean'] = df.groupby('permno')['ret_60_mean'].shift(-1)

df['xs_ret'] = df['ret'] - df['ret_60_mean']

# Explanatory Variables
def create_lags(df, lags, column='ret'):
    for lag in lags:
        df[f'{column}_lag_{lag}'] = df.groupby('permno')[column].shift(lag)
    return df

lags = list(range(1, 13)) + [24, 36]

df = create_lags(df, lags)
df = df.dropna()

df
# Out:
#          permno ticker       date      prc       ret      mdt  month  year  \
# 405       10006    ACF 1962-07-31  67.5000  0.144068  1962-07      7  1962
# 406       10006    ACF 1962-08-31  67.1250  0.003704  1962-08      8  1962
# 407       10006    ACF 1962-09-28  63.5000 -0.054004  1962-09      9  1962
# 408       10006    ACF 1962-10-31  68.0000  0.070866  1962-10     10  1962
# 409       10006    ACF 1962-11-30  72.8750  0.080882  1962-11     11  1962
# ...         ...    ...        ...      ...       ...      ...    ...   ...
# 1226386   86239     CF 1971-07-30  20.5000 -0.052023  1971-07      7  1971
# 1226387   86239     CF 1971-08-31  23.8750  0.174390  1971-08      8  1971
# 1226388   86239     CF 1971-09-30  22.4375 -0.060209  1971-09      9  1971
# 1226389   86239     CF 1971-10-29  21.7500 -0.030641  1971-10     10  1971
# 1226390   86239     CF 1971-11-30  22.5000  0.034483  1971-11     11  1971
#
#          ret_60_mean    xs_ret  ...  ret_lag_5  ret_lag_6  ret_lag_7  \
# 405         0.012450  0.131618  ...   0.011986   0.087523   0.082661
# 406         0.013075 -0.009371  ...  -0.071672   0.011986   0.087523
# 407         0.014700 -0.068704  ...   0.056985  -0.071672   0.011986
# 408         0.018294  0.052572  ...  -0.160000   0.056985  -0.071672
# 409         0.016951  0.063931  ...  -0.012552  -0.160000   0.056985
# ...              ...       ...  ...        ...        ...        ...
# 1226386     0.020030 -0.072053  ...   0.060000   0.025641   0.106383
# 1226387     0.019370  0.155020  ...   0.000000   0.060000   0.025641
# 1226388     0.012771 -0.072980  ...   0.184524   0.000000   0.060000
# 1226389     0.013355 -0.043996  ...  -0.082412   0.184524   0.000000
# 1226390     0.011828  0.022655  ...  -0.082412  -0.082412   0.184524
#
#          ret_lag_8  ret_lag_9  ret_lag_10  ret_lag_11  ret_lag_12  ret_lag_24  \
# 405       0.043750   0.043478   -0.033613    0.006276    0.066964   -0.013514
# 406       0.082661   0.043750    0.043478   -0.033613    0.006276   -0.021918
# 407       0.087523   0.082661    0.043750    0.043478   -0.033613   -0.142045
# 408       0.011986   0.087523    0.082661    0.043750    0.043478   -0.013245
# 409      -0.071672   0.011986    0.087523    0.082661    0.043750    0.003356
# ...            ...        ...         ...         ...         ...         ...
# 1226386   0.004225  -0.003509   -0.080645    0.003846    0.026316   -0.044681
# 1226387   0.106383   0.004225   -0.003509   -0.080645    0.003846   -0.016854
# 1226388   0.025641   0.106383    0.004225   -0.003509   -0.080645   -0.085714
# 1226389   0.060000   0.025641    0.106383    0.004225   -0.003509    0.013750
# 1226390   0.000000   0.060000    0.025641    0.106383    0.004225    0.013750
#
#          ret_lag_36
# 405        0.064838
# 406        0.056206
# 407       -0.067265
# 408       -0.038462
# 409       -0.030000
# ...             ...
# 1226386    0.049351
# 1226387    0.025000
# 1226388    0.021951
# 1226389    0.090361
# 1226390    0.138122
#
# [466866 rows x 24 columns]

# %%
formula = 'xs_ret ~ ' + ' + '.join([f'ret_lag_{lag}' for lag in lags])

mdts = df['mdt'].unique()

result_df_list = []

for mdt in mdts:
    # Filter data for the current year
    slice_df = df[df['mdt'] == mdt].copy()
    
    # Fit the OLS regression model using the formula syntax
    model = smf.ols(formula=formula, data=slice_df)
    result = model.fit()
    
    result_df = pd.DataFrame()
    
    result_df['name'] = ['intercept'] + [f'ret_lag_{lag}' for lag in lags]
    result_df['mdt'] = mdt
    result_df['coef'] = result.params.values
    result_df['t_stat'] = result.tvalues.values

    result_df_list.append(result_df)

# Display the resulting DataFrame
combined = pd.concat(result_df_list)

combined
# Out:
#           name      mdt      coef    t_stat
# 0    intercept  1962-07  0.008132  1.330148
# 1    ret_lag_1  1962-07 -0.211372 -5.065103
# 2    ret_lag_2  1962-07 -0.288598 -7.055987
# 3    ret_lag_3  1962-07 -0.002950 -0.069007
# 4    ret_lag_4  1962-07  0.091284  2.252773
# ..         ...      ...       ...       ...
# 10  ret_lag_10  1962-06 -0.011587 -0.000000
# 11  ret_lag_11  1962-06 -0.042844 -0.000000
# 12  ret_lag_12  1962-06  0.042117  0.000000
# 13  ret_lag_24  1962-06  0.009649  0.000000
# 14  ret_lag_36  1962-06 -0.068965 -0.000000
#
# [5835 rows x 4 columns]

# %%
combined[['name','coef', 't_stat']].groupby("name").mean().T
# Out:
# name    intercept  ret_lag_1  ret_lag_10  ret_lag_11  ret_lag_12  ret_lag_2  \
# coef     0.001341  -0.048898   -0.005372   -0.000596    0.007627  -0.007672
# t_stat  -0.172790  -2.176215   -0.242783   -0.151941    0.239002  -0.595847
#
# name    ret_lag_24  ret_lag_3  ret_lag_36  ret_lag_4  ret_lag_5  ret_lag_6  \
# coef     -0.006813   0.003310   -0.007585   0.005138  -0.000206  -0.001202
# t_stat   -0.207120  -0.048056   -0.254095   0.093586  -0.090520  -0.130370
#
# name    ret_lag_7  ret_lag_8  ret_lag_9
# coef    -0.002487  -0.006768  -0.006442
# t_stat  -0.163849  -0.206831  -0.170576
